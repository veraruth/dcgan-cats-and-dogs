# %%
from PIL import Image
import os
 
file_name = "train-6"
file_format = ".png"

im = Image.open(file_name + file_format)

count = 0

path = os.getcwd() + "/save_folder"
os.mkdir(path)

# first row
# left = 16
# top = 16
# right = 112
# bottom = 112

# left = 16 * 8
# top = 16
# right = 112 + 112
# bottom = 112

# left = 16 * 15
# top = 16
# right = 112 + 112 + 112
# bottom = 112

# left = 16 * 22
# top = 16
# right = 112 + 112 + 112 + 112
# bottom = 112

# left = 16 * 29
# top = 16
# right = 112 + 112 + 112 + 112 + 112
# bottom = 112

# left = 16 * 36
# top = 16
# right = 112 + 112 + 112 + 112 + 112 + 112
# bottom = 112

# left = 16 * 43
# top = 16
# right = 112 + 112 + 112 + 112 + 112 + 112 + 112
# bottom = 112

val = 8
for i in range(7):
    count += 1
    if i == 0:
        left = 16
        top = 16
        right = 112
        bottom = 112
    
    elif i == 1:
        left = 16 * val
        top = 16
        right += 112
        bottom = 112
        
    else:
        val += 7
        left = 16 * val
        top = 16
        right += 112
        bottom = 112
        
    im1 = im.crop((left, top, right, bottom))
    im1.save(path + "/" + file_name + "-" + str(count) + file_format)

#second row
# left = 16
# top = 128
# right = 112
# bottom = 112 + 112

# left = 16 * 8
# top = 128
# right = 112 + 112
# bottom = 112 + 112

val = 8
for i in range(7):
    count += 1
    if i == 0:
        left = 16
        top = 128
        right = 112
        bottom = 112 + 112
    
    elif i == 1:
        left = 16 * val
        top = 128
        right += 112
        bottom = 112 + 112
        
    else:
        val += 7
        left = 16 * val
        top = 128
        right += 112
        bottom = 112 + 112
        
    im1 = im.crop((left, top, right, bottom))
    im1.save(path + "/" + file_name + "-" + str(count) + file_format)
    

#third row
# left = 16
# top = 128 + 112
# right = 112
# bottom = 112 + 112 + 112

# left = 16 * 8
# top = 128 + 112
# right = 112 + 112
# bottom = 112 + 112 + 112

val = 8
for i in range(7):
    count += 1
    if i == 0:
        left = 16
        top = 128 + 112
        right = 112
        bottom = 112 + 112 + 112
    
    elif i == 1:
        left = 16 * val
        top = 128 + 112
        right += 112
        bottom = 112 + 112 + 112
        
    else:
        val += 7
        left = 16 * val
        top = 128 + 112
        right += 112
        bottom = 112 + 112 + 112
        
    im1 = im.crop((left, top, right, bottom))
    im1.save(path + "/" + file_name + "-" + str(count) + file_format)

#fourth row
# left = 16
# top = 128 + 112 + 112
# right = 112
# bottom = 112 + 112 + 112 + 112

# left = 16 * 8
# top = 128 + 112 + 112
# right = 112 + 112
# bottom = 112 + 112 + 112 + 112

val = 8
for i in range(7):
    count += 1
    if i == 0:
        left = 16
        top = 128 + 112 + 112
        right = 112
        bottom = 112 + 112 + 112 + 112
    
    elif i == 1:
        left = 16 * val
        top = 128 + 112 + 112
        right += 112
        bottom = 112 + 112 + 112 + 112
        
    else:
        val += 7
        left = 16 * val
        top = 128 + 112 + 112
        right += 112
        bottom = 112 + 112 + 112 + 112
        
    im1 = im.crop((left, top, right, bottom))
    im1.save(path + "/" + file_name + "-" + str(count) + file_format)
